# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
#导入数据
data = pd.read_csv("数据.csv",encoding='gbk')
data.head()  #查看前5行
# Out:
#    id  type      a1     a2     a3     a4     a5     a6     a7     a8  ...  B9  \
# 0   1     2  753.04  87.65  81.56  85.61  85.63  85.81  82.35  84.77  ...   6
# 1   2     3   88.92  82.95  85.17  85.19  77.76  83.60  82.15  88.87  ...   6
# 2   3     3   95.05  93.33  77.66  93.03  88.87  94.17  95.60  95.88  ...   4
# 3   4     3   71.15  76.79  66.69  81.93  66.65  77.77  77.58  76.99  ...   6
# 4   5     3   70.57  71.65  70.44  74.03  66.65  66.34  62.09  74.44  ...   6
#
#    B10  B11  B12   B13  B14 B15  B16  B17  will
# 0   14    2    3  19.0   11  10   30    5     0
# 1    5    4    4  18.0   10   8    0   30     0
# 2    9    5    2  24.0   10  17    0    0     0
# 3   10    4    7  27.0   10  10   18   25     0
# 4   13    4    2  25.0   15  15    0    0     0
#
# [5 rows x 28 columns]

# %%
#将数据类型设置为DataFrame
df=pd.DataFrame(data)
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#提取单列

#df.id
a=df["a2"]
#df.iloc[:,0]

type(a)
# Out:
# pandas.core.series.Series

# %%
#提取多列

b=df.iloc[:,2:4]
b
#b.drop(b[b.a2==93.33],axis=1,inplace=True)
#b[b.a2==93.33]

#将特定值转化为NaN
b.iloc[:,1]=b.iloc[:,1].apply(lambda x: np.nan if x==93.33 else x)
b
# Out:
#           a1     a2
# 0     753.04  87.65
# 1      88.92  82.95
# 2      95.05    NaN
# 3      71.15  76.79
# 4      70.57  71.65
# ...      ...    ...
# 1959   71.36  75.37
# 1960   99.04  99.03
# 1961   90.77  91.92
# 1962   82.43  88.51
# 1963   77.81  77.80
#
# [1964 rows x 2 columns]

# %%
#提取多个不连续列
df.iloc[:,[1,4]]
# Out:
#       type      a3
# 0        2   81.56
# 1        3   85.17
# 2        3   77.66
# 3        3   66.69
# 4        3   70.44
# ...    ...     ...
# 1959     2   70.44
# 1960     2   99.03
# 1961     2   92.67
# 1962     2   74.05
# 1963     2  703.00
#
# [1964 rows x 2 columns]

# %%
#提取多个不连续列
df[["a2","a3"]]
# Out:
#          a2      a3
# 0     87.65   81.56
# 1     82.95   85.17
# 2     93.33   77.66
# 3     76.79   66.69
# 4     71.65   70.44
# ...     ...     ...
# 1959  75.37   70.44
# 1960  99.03   99.03
# 1961  91.92   92.67
# 1962  88.51   74.05
# 1963  77.80  703.00
#
# [1964 rows x 2 columns]

# %%
#小提琴图
sns.violinplot(data=pd.DataFrame(df.a1))#,inner="point"
# Out:
# <AxesSubplot:>

# %%
c=df[["a1","a2","a3","a4","a5","a6","a7","a8"]]
sns.violinplot(data=c)
# Out:
# <AxesSubplot:>
